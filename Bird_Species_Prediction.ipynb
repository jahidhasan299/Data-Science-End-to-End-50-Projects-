# %% [markdown]
# <a href="https://colab.research.google.com/github/jahidhasan299/Data-Science-End-to-End-50-Projects-/blob/main/Bird_Species_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # THE STEPS ARE TAKEN TO COMPLETE THIS PROBLEM
# 1. Mounting google drive on colab notebook
# 2. Visualizing the image that we will be working on
# 3. Analyzing the dimensions to verify if all images have same dimensions.
# 4. Converting the images into a numpy array and normilize them.
# 5. Checking class imbalance
# 6. Spliting the data and performing one-hot encoding
# 7. Creating the model architecture, compliling the mode and fit it.
# 8. Plotting the accuracy and loss against each epoch.
# 9. Preprocessing the test data and make predicting onit.
# 10. Visualizing the orginal and predicted labels for the test images

# %% [markdown]
# # Bird Species Prediction

# %% [markdown]
# In this project we will create a Convolutional Neural Network which will be able to predict species of the bird. We will use different layers and other hyperparameters for building, training and testing this multiclass classifictaion model. We will be using keras for this project.
# # Usefull of this Project
# This project can be used for educational purposes to get a better understanding of how create network architectute for a CNN model. You can further hyperparameter tune this model to reach higher accuracy. It can be used by bird sanctuaries to indetify differnt types of birds.

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# First we will mount our google drive on colab so that we can use the dataset directly from our drive. For this you first need to upload the data on your drive and then mount the drive on colab.

# %%
# After executing the cell above, Drive files will be present in "/content/drive/My Drive".
# !ls "/content/drive/MyDrive/Colab Notebooks/Data Science End-to-End [50] Project/Data/Data (1)"
# Out:
# 'Bird Speciees Dataset'

# %% [markdown]
# After mounting our drive we will locate the folder where our data is stored to use it in our colab notebook. Here you can see that all the folders I have in my drive and 'Bird Species Dataset' contains the images that we will work on.

# %%
# Library imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split

# %% [markdown]
# We will start by importing some required libraries.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/MyDrive/Colab Notebooks/Data Science End-to-End [50] Project/Data/Data (1)/Bird Speciees Dataset/AMERICAN GOLDFINCH"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# Let's visualize some of the bird images that we will be working on. Also we will observe x and y dimensions of the image.

# %%
# Setting path and creating empty list
dir = "/content/drive/MyDrive/Colab Notebooks/Data Science End-to-End [50] Project/Data/Data (1)/Bird Speciees Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []

# %% [markdown]
# Setting the root directory for the dataset and storing all the floders name of the dataset. We will also create 2 empty list for image and lables.

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = cv2.imread(image_path)
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %% [markdown]
# Next we will read all the images and convert it into array and appending the list created above with the image and its label.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# AMERICAN GOLDFINCH    143
# EMPEROR PENGUIN       139
# DOWNY WOODPECKER      137
# FLAMINGO              132
# CARMINE BEE-EATER     131
# BARN OWL              129
# dtype: int64

# %% [markdown]
# Check for class imbalance.

# %%
# Storing number of classes
num_classes = len(label_counts)
num_classes
# Out:
# 6

# %% [markdown]
# Next we will find out the number of classes that we will be working on.

# %%
# Checking input image shape
image_list[0].shape
# Out:
# (224, 224, 3)

# %% [markdown]
# Checking the size of the single image.

# %%
# Checking labels shape 
label_list = np.array(label_list)
label_list.shape
# Out:
# (811,)

# %% [markdown]
# Checking the shape of image labels which will be equal to the number of images we are going to work with.

# %%
# Splitting dataset
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Now we will split the data into training and testing using train_test_split() of sklearn.

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 224,224,3)
x_test = x_test.reshape( -1, 224,224,3)

# %% [markdown]
# Next we will normalize the images by dividing them with 255. Also, we will reshape x_train and x_test.

# %%
# Label binarizing
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']

# %% [markdown]
# Next we will use label binarizer to one hot encode our y data. We will also print the sequence of the classes.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Now we will split the training data to validation and training data.

# %%
# Building model architecture
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same",input_shape=(224,224,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(32, activation="relu"))
model.add(Dense(num_classes, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 8)       224
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 74, 74, 16)        1168
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 32)                331808
#
#  dense_1 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 338,038
# Trainable params: 338,038
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel). In the last layer we will use softmax as the activation function because it is a multi class classification problem.

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005),metrics=['accuracy'])

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Categorical Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 14s 204ms/step - loss: 1.8733 - accuracy: 0.2008 - val_loss: 2.0644 - val_accuracy: 0.1615
# Epoch 2/50
# 5/5 [==============================] - 0s 85ms/step - loss: 1.9445 - accuracy: 0.2181 - val_loss: 1.7288 - val_accuracy: 0.2846
# Epoch 3/50
# 5/5 [==============================] - 0s 80ms/step - loss: 1.7489 - accuracy: 0.2066 - val_loss: 1.7432 - val_accuracy: 0.1462
# Epoch 4/50
# 5/5 [==============================] - 0s 82ms/step - loss: 1.7325 - accuracy: 0.2220 - val_loss: 1.6766 - val_accuracy: 0.3846
# Epoch 5/50
# 5/5 [==============================] - 0s 81ms/step - loss: 1.6911 - accuracy: 0.2703 - val_loss: 1.7006 - val_accuracy: 0.2231
# Epoch 6/50
# 5/5 [==============================] - 0s 83ms/step - loss: 1.6723 - accuracy: 0.2490 - val_loss: 1.6779 - val_accuracy: 0.2308
# Epoch 7/50
# 5/5 [==============================] - 0s 83ms/step - loss: 1.6003 - accuracy: 0.3784 - val_loss: 1.5731 - val_accuracy: 0.4846
# Epoch 8/50
# 5/5 [==============================] - 0s 80ms/step - loss: 1.5458 - accuracy: 0.4884 - val_loss: 1.4714 - val_accuracy: 0.5692
# Epoch 9/50
# 5/5 [==============================] - 0s 84ms/step - loss: 1.4196 - accuracy: 0.5444 - val_loss: 1.4418 - val_accuracy: 0.4385
# Epoch 10/50
# 5/5 [==============================] - 0s 81ms/step - loss: 1.3571 - accuracy: 0.4884 - val_loss: 1.2449 - val_accuracy: 0.6077
# Epoch 11/50
# 5/5 [==============================] - 0s 81ms/step - loss: 1.2575 - accuracy: 0.5734 - val_loss: 1.1977 - val_accuracy: 0.5923
# Epoch 12/50
# 5/5 [==============================] - 0s 81ms/step - loss: 1.1477 - accuracy: 0.6178 - val_loss: 1.1760 - val_accuracy: 0.5615
# Epoch 13/50
# 5/5 [==============================] - 0s 80ms/step - loss: 1.1459 - accuracy: 0.5888 - val_loss: 1.0987 - val_accuracy: 0.6308
# Epoch 14/50
# 5/5 [==============================] - 0s 82ms/step - loss: 1.0652 - accuracy: 0.6274 - val_loss: 1.1213 - val_accuracy: 0.5769
# Epoch 15/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.9363 - accuracy: 0.6564 - val_loss: 0.9907 - val_accuracy: 0.6231
# Epoch 16/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.9030 - accuracy: 0.6680 - val_loss: 0.9743 - val_accuracy: 0.6154
# Epoch 17/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.8478 - accuracy: 0.7548 - val_loss: 1.0010 - val_accuracy: 0.6231
# Epoch 18/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.8191 - accuracy: 0.6853 - val_loss: 0.7957 - val_accuracy: 0.7538
# Epoch 19/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.7316 - accuracy: 0.7606 - val_loss: 0.7981 - val_accuracy: 0.7308
# Epoch 20/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.6481 - accuracy: 0.8185 - val_loss: 0.9053 - val_accuracy: 0.6231
# Epoch 21/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.6222 - accuracy: 0.7915 - val_loss: 0.7413 - val_accuracy: 0.7000
# Epoch 22/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.6173 - accuracy: 0.8031 - val_loss: 0.6938 - val_accuracy: 0.8000
# Epoch 23/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.5234 - accuracy: 0.8649 - val_loss: 0.7141 - val_accuracy: 0.7692
# Epoch 24/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.4857 - accuracy: 0.8668 - val_loss: 0.7208 - val_accuracy: 0.7154
# Epoch 25/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.5008 - accuracy: 0.8147 - val_loss: 0.6487 - val_accuracy: 0.7923
# Epoch 26/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.4346 - accuracy: 0.8784 - val_loss: 0.6589 - val_accuracy: 0.7692
# Epoch 27/50
# 5/5 [==============================] - 0s 83ms/step - loss: 0.4059 - accuracy: 0.8803 - val_loss: 0.6279 - val_accuracy: 0.7692
# Epoch 28/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.3843 - accuracy: 0.8958 - val_loss: 0.6656 - val_accuracy: 0.7462
# Epoch 29/50
# 5/5 [==============================] - 0s 83ms/step - loss: 0.3320 - accuracy: 0.9151 - val_loss: 0.6158 - val_accuracy: 0.8077
# Epoch 30/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.3535 - accuracy: 0.9054 - val_loss: 0.6167 - val_accuracy: 0.8231
# Epoch 31/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.3062 - accuracy: 0.9189 - val_loss: 0.5402 - val_accuracy: 0.8462
# Epoch 32/50
# 5/5 [==============================] - 0s 83ms/step - loss: 0.3053 - accuracy: 0.9266 - val_loss: 0.5449 - val_accuracy: 0.8308
# Epoch 33/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.2795 - accuracy: 0.9228 - val_loss: 0.5584 - val_accuracy: 0.8000
# Epoch 34/50
# 5/5 [==============================] - 0s 84ms/step - loss: 0.2345 - accuracy: 0.9459 - val_loss: 0.5102 - val_accuracy: 0.8615
# Epoch 35/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.2092 - accuracy: 0.9595 - val_loss: 0.6049 - val_accuracy: 0.8077
# Epoch 36/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.2121 - accuracy: 0.9402 - val_loss: 0.5014 - val_accuracy: 0.8538
# Epoch 37/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1716 - accuracy: 0.9633 - val_loss: 0.5057 - val_accuracy: 0.8385
# Epoch 38/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1855 - accuracy: 0.9653 - val_loss: 0.4941 - val_accuracy: 0.8769
# Epoch 39/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.1426 - accuracy: 0.9749 - val_loss: 0.4443 - val_accuracy: 0.8615
# Epoch 40/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1342 - accuracy: 0.9807 - val_loss: 0.5061 - val_accuracy: 0.8462
# Epoch 41/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1477 - accuracy: 0.9672 - val_loss: 0.4901 - val_accuracy: 0.8462
# Epoch 42/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1262 - accuracy: 0.9807 - val_loss: 0.4515 - val_accuracy: 0.8769
# Epoch 43/50
# 5/5 [==============================] - 0s 83ms/step - loss: 0.1180 - accuracy: 0.9807 - val_loss: 0.4669 - val_accuracy: 0.8769
# Epoch 44/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.1224 - accuracy: 0.9710 - val_loss: 0.4630 - val_accuracy: 0.8923
# Epoch 45/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1009 - accuracy: 0.9807 - val_loss: 0.4150 - val_accuracy: 0.9077
# Epoch 46/50
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0867 - accuracy: 0.9903 - val_loss: 0.4397 - val_accuracy: 0.8846
# Epoch 47/50
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0807 - accuracy: 0.9884 - val_loss: 0.4641 - val_accuracy: 0.8538
# Epoch 48/50
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0799 - accuracy: 0.9846 - val_loss: 0.4170 - val_accuracy: 0.8923
# Epoch 49/50
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0748 - accuracy: 0.9923 - val_loss: 0.4307 - val_accuracy: 0.8846
# Epoch 50/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0891 - accuracy: 0.9826 - val_loss: 0.4330 - val_accuracy: 0.8923

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 50 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already reached a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Saving model
model.save("/content/drive/MyDrive/Colab Notebooks/Data Science End-to-End [50] Project/Data/Data (1)/bird_species.h5")

# %% [markdown]
# Now we will save the model in h5 format to use it later for prediction.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the training history.

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Here we will plot the loss of the model for the training history.

# %%
# Calculating test accuracy
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 6/6 [==============================] - 0s 26ms/step - loss: 0.5485 - accuracy: 0.8098
# Test Accuracy: 80.98159432411194

# %% [markdown]
# Evaluating the model to know the accuracy of the model on the test data.

# %%
# Storing predictions
y_pred = model.predict(x_test)

# %% [markdown]
# Here we are storing prediction on test data.

# %%
# Plotting image to compare
img = array_to_img(x_test[5])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F1E985818D0>

# %% [markdown]
# Visualizing one of the image which we will be further used for prediction.

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[5])])
print("Predicted : ",labels[np.argmax(y_pred[5])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']
# Originally :  FLAMINGO
# Predicted :  FLAMINGO

# %% [markdown]
# Now, we will create list of labels using object of label binarizer. We will print that list and finally we will print out the prediction and the original label of the image we visualized above using argmax().

# %% [markdown]
# # Conclusion:

# %% [markdown]
# We started with loading the dataset into google colab using google drive and visualizing the images. Normalizing is an important step when working with any type of dataset. After that we created a CNN Model which is further used for predicting the bird species using the image supplied to model.

# %% [markdown]
# # Scope:

# %% [markdown]
# This project can be used for educational purposes to get a better understanding of how to create network architecture for a CNN model. You can further hyper parameter tune this model to reach a higher accuracy. It can be used by bird sanctuaries to identify different types of birds.

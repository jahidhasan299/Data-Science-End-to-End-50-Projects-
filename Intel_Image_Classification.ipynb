# %% [markdown]
# <a href="https://colab.research.google.com/github/jahidhasan299/Data-Science-End-to-End-50-Projects-/blob/main/Intel_Image_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # THE STEPS ARE TAKEN TO COMPLETE THIS PROBLEM
# 1. Mounting google drive on colab notebook
# 2. Visualizing the image that we will be working on
# 3. Analyzing the dimensions to verify if all images have same dimensions.
# 4. Converting the images into a numpy array and normilize them.
# 5. Checking class imbalance
# 6. Spliting the data and performing one-hot encoding
# 7. Creating the model architecture, compliling the mode and fit it.
# 8. Plotting the accuracy and loss against each epoch.
# 9. Preprocessing the test data and make predicting onit.
# 10. Visualizing the orginal and predicted labels for the test images

# %% [markdown]
# # Intel Image Classification

# %% [markdown]
# In this project, we will be working on Intel images i.e. images of buildings, forest, street, etc. We will built a convolutional neural network and train it on this images. This is a multi class classification problem and we will use Keras.

# %% [markdown]
# # Usefull of this Project
# This project can be used for educational purposes to get a better understanding of how create network architectute for a CNN model. You can further hyperparameter tune this model to reach higher accuracy.
#
# This project has vast scope, IT can be used to classify satellite images, drone images, google images into differnt classses like sea, mountain etc.

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# First we will mount our google drive on colab so that we can use the dataset directly from our drive. For this you first need to upload the data on your drive and then mount the drive on colab.

# %%
# After executing the cell above, Drive files will be present in "/content/drive/My Drive".
# !ls "/content/drive/MyDrive/Colab Notebooks/Data Science End-to-End [50] Project/Data/Data (2)"
# Out:
# 'Intel Image Dataset'

# %% [markdown]
# After mounting our drive we will locate the folder where our data is stored to use it in our colab notebook. Here we will see all the folders I have in my drive and 'Intel Image Dataset' contains the images that we will work on.

# %%
# Important imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.optimizers import Adam
from PIL import Image
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense, LeakyReLU
from sklearn.model_selection import train_test_split

# %% [markdown]
# We will start by importing some required libraries.

# %%
# Listing directory
# !ls "/content/drive/MyDrive/Colab Notebooks/Data Science End-to-End [50] Project/Data/Data (2)/Intel Image Dataset"
# Out:
# buildings  forest  glacier  mountain  sea  street

# %% [markdown]
# We will check for folders of class images.

# %%
# Plotting 25 images to check dataset
plt.figure(figsize=(11,11))
path = "/content/drive/MyDrive/Colab Notebooks/Data Science End-to-End [50] Project/Data/Data (2)/Intel Image Dataset/mountain"
for i in range(1,26):
    plt.subplot(5,5,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.title('mountain')
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# Let's visualize some of the mountain images that we will be working on. Also we will observe x and y dimensions of the image.

# %%
# Setting root directory path and creating empty list
dir = "/content/drive/MyDrive/Colab Notebooks/Data Science End-to-End [50] Project/Data/Data (2)/Intel Image Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []

# %% [markdown]
# Setting the root directory for the dataset and storing all the folders name of the dataset. We will also create 2 empty list for image and lables.

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = Image.open(image_path)
    image = image.resize((150,150)) # All images does not have same dimension
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %% [markdown]
# Next we need to resize images as some of the images don't have same dimensions. So, we will read and resize all the images. Then we will convert it into array and appending the list created above with the image and its label.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# glacier      553
# mountain     525
# sea          510
# street       501
# forest       474
# buildings    437
# dtype: int64

# %% [markdown]
# Checking for images per class.

# %%
# Checking count of classes
num_classes = len(label_counts)
num_classes
# Out:
# 6

# %% [markdown]
# Storing the number of classes which will be used further in model architecture.

# %%
# Checking x data shape
np.array(image_list).shape
# Out:
# (3000, 150, 150, 3)

# %% [markdown]
# Check the shape of the x data for input layer of model architecture.

# %%
# Checking y data shape
label_list = np.array(label_list)
label_list.shape
# Out:
# (3000,)

# %% [markdown]
# Checking the number of labels in y data which should be equal to total number of images.

# %%
# Splitting dataset into test and train
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Now we will split our dataset into testing and training using train_test_split() from sklearn.

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 150,150,3)
x_test = x_test.reshape( -1, 150,150,3)

# %% [markdown]
# Next we will normalize the images by dividing them with 255 and we will also reshape x_train and x_test data.

# %%
# Binarizing labels
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['buildings' 'forest' 'glacier' 'mountain' 'sea' 'street']

# %% [markdown]
# Here we will use label binarizer to one hot encode our y data. We will also print the sequence of the classes.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Now we will split the training data to validation and training data.

# %%
# Creating model architecture
model = Sequential([
        Conv2D(16, kernel_size = (3,3), input_shape = (150,150,3)),
        BatchNormalization(),
        LeakyReLU(),
          
        Conv2D(32, kernel_size = (3,3)),
        BatchNormalization(),
        LeakyReLU(),
        MaxPooling2D(5,5),
        
        Conv2D(64, kernel_size = (3,3)),
        BatchNormalization(),
        LeakyReLU(),
        
        Conv2D(128, kernel_size = (3,3)),
        BatchNormalization(),
        LeakyReLU(),
        MaxPooling2D(5,5),

        Flatten(),
    
        Dense(64),
        Dropout(rate = 0.2),
        BatchNormalization(),
        LeakyReLU(),
        
        Dense(32),
        Dropout(rate = 0.2),
        BatchNormalization(),
        LeakyReLU(),
    
        Dense(16),
        Dropout(rate = 0.2),
        BatchNormalization(),
        LeakyReLU(1),
    
        Dense(6, activation = 'softmax')    
        ])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  batch_normalization (BatchN  (None, 148, 148, 16)     64
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 148, 148, 16)      0
#
#  conv2d_1 (Conv2D)           (None, 146, 146, 32)      4640
#
#  batch_normalization_1 (Batc  (None, 146, 146, 32)     128
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 146, 146, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 29, 29, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 27, 27, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 27, 27, 64)       256
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 27, 27, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 25, 25, 128)       73856
#
#  batch_normalization_3 (Batc  (None, 25, 25, 128)      512
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 25, 25, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 64)                204864
#
#  dropout (Dropout)           (None, 64)                0
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  batch_normalization_5 (Batc  (None, 32)               128
#  hNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  batch_normalization_6 (Batc  (None, 16)               64
#  hNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 16)                0
#
#  dense_3 (Dense)             (None, 6)                 102
#
# =================================================================
# Total params: 306,422
# Trainable params: 305,718
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# Now we will create a network architecture for the model. We have used different types of layers according to their features namely BatchNormalization (Batch normalization is a technique for training very deep neural networks that standardizes the inputs to a layer for each mini-batch), LeakyRelu (The Leaky ReLU modifies the function to allow small negative values when the input is less than zero), Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel). In the last layer we will use softmax as the activation function because it is a multi class classification problem.

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005),metrics=['accuracy'])

# %% [markdown]
# For compiling the model we need to pass 3 parameters namely loss, optimizer and metrics. Here we will use loss as categorical_crossentropy, optimizer as Adam and metrics as accuracy.

# %%
# Training the model
epochs = 60
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/60
# 15/15 [==============================] - 2s 151ms/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.7870 - val_accuracy: 0.7729
# Epoch 2/60
# 15/15 [==============================] - 2s 138ms/step - loss: 0.0244 - accuracy: 0.9995 - val_loss: 0.8166 - val_accuracy: 0.7375
# Epoch 3/60
# 15/15 [==============================] - 2s 138ms/step - loss: 0.0218 - accuracy: 0.9995 - val_loss: 0.8969 - val_accuracy: 0.7396
# Epoch 4/60
# 15/15 [==============================] - 2s 138ms/step - loss: 0.0246 - accuracy: 0.9995 - val_loss: 0.8723 - val_accuracy: 0.7354
# Epoch 5/60
# 15/15 [==============================] - 2s 138ms/step - loss: 0.0232 - accuracy: 1.0000 - val_loss: 0.8085 - val_accuracy: 0.7583
# Epoch 6/60
# 15/15 [==============================] - 2s 138ms/step - loss: 0.0224 - accuracy: 0.9990 - val_loss: 0.7682 - val_accuracy: 0.7667
# Epoch 7/60
# 15/15 [==============================] - 2s 139ms/step - loss: 0.0217 - accuracy: 0.9995 - val_loss: 0.9138 - val_accuracy: 0.7542
# Epoch 8/60
# 15/15 [==============================] - 2s 139ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.7517 - val_accuracy: 0.7729
# Epoch 9/60
# 15/15 [==============================] - 2s 140ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.7589 - val_accuracy: 0.7688
# Epoch 10/60
# 15/15 [==============================] - 2s 140ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.7855 - val_accuracy: 0.7583
# Epoch 11/60
# 15/15 [==============================] - 2s 149ms/step - loss: 0.0186 - accuracy: 0.9995 - val_loss: 0.8240 - val_accuracy: 0.7417
# Epoch 12/60
# 15/15 [==============================] - 2s 141ms/step - loss: 0.0194 - accuracy: 0.9995 - val_loss: 0.8447 - val_accuracy: 0.7521
# Epoch 13/60
# 15/15 [==============================] - 2s 140ms/step - loss: 0.0194 - accuracy: 0.9995 - val_loss: 0.9351 - val_accuracy: 0.7417
# Epoch 14/60
# 15/15 [==============================] - 2s 146ms/step - loss: 0.0255 - accuracy: 0.9969 - val_loss: 1.2631 - val_accuracy: 0.6583
# Epoch 15/60
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0298 - accuracy: 0.9964 - val_loss: 1.1265 - val_accuracy: 0.7042
# Epoch 16/60
# 15/15 [==============================] - 2s 140ms/step - loss: 0.0307 - accuracy: 0.9974 - val_loss: 1.0846 - val_accuracy: 0.6812
# Epoch 17/60
# 15/15 [==============================] - 2s 139ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.9046 - val_accuracy: 0.7604
# Epoch 18/60
# 15/15 [==============================] - 2s 141ms/step - loss: 0.0202 - accuracy: 0.9995 - val_loss: 0.9490 - val_accuracy: 0.7417
# Epoch 19/60
# 15/15 [==============================] - 2s 141ms/step - loss: 0.0181 - accuracy: 0.9995 - val_loss: 0.8429 - val_accuracy: 0.7625
# Epoch 20/60
# 15/15 [==============================] - 2s 142ms/step - loss: 0.0184 - accuracy: 0.9984 - val_loss: 0.8398 - val_accuracy: 0.7604
# Epoch 21/60
# 15/15 [==============================] - 2s 140ms/step - loss: 0.0209 - accuracy: 0.9984 - val_loss: 0.8653 - val_accuracy: 0.7542
# Epoch 22/60
# 15/15 [==============================] - 2s 141ms/step - loss: 0.0215 - accuracy: 0.9995 - val_loss: 0.9894 - val_accuracy: 0.7292
# Epoch 23/60
# 15/15 [==============================] - 2s 142ms/step - loss: 0.0216 - accuracy: 0.9990 - val_loss: 1.0107 - val_accuracy: 0.7604
# Epoch 24/60
# 15/15 [==============================] - 2s 152ms/step - loss: 0.0201 - accuracy: 0.9990 - val_loss: 0.8109 - val_accuracy: 0.7750
# Epoch 25/60
# 15/15 [==============================] - 2s 142ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.9205 - val_accuracy: 0.7479
# Epoch 26/60
# 15/15 [==============================] - 2s 142ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.7971 - val_accuracy: 0.7896
# Epoch 27/60
# 15/15 [==============================] - 2s 143ms/step - loss: 0.0160 - accuracy: 0.9995 - val_loss: 0.8871 - val_accuracy: 0.7479
# Epoch 28/60
# 15/15 [==============================] - 2s 143ms/step - loss: 0.0158 - accuracy: 0.9995 - val_loss: 0.9417 - val_accuracy: 0.7500
# Epoch 29/60
# 15/15 [==============================] - 2s 142ms/step - loss: 0.0227 - accuracy: 0.9969 - val_loss: 0.9614 - val_accuracy: 0.7396
# Epoch 30/60
# 15/15 [==============================] - 2s 143ms/step - loss: 0.0216 - accuracy: 0.9990 - val_loss: 1.1477 - val_accuracy: 0.7021
# Epoch 31/60
# 15/15 [==============================] - 2s 142ms/step - loss: 0.0191 - accuracy: 0.9995 - val_loss: 0.9160 - val_accuracy: 0.7583
# Epoch 32/60
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.9795 - val_accuracy: 0.7292
# Epoch 33/60
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0179 - accuracy: 0.9995 - val_loss: 1.0079 - val_accuracy: 0.7354
# Epoch 34/60
# 15/15 [==============================] - 2s 145ms/step - loss: 0.0165 - accuracy: 0.9995 - val_loss: 0.9528 - val_accuracy: 0.7583
# Epoch 35/60
# 15/15 [==============================] - 2s 143ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.8370 - val_accuracy: 0.7708
# Epoch 36/60
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.8631 - val_accuracy: 0.7646
# Epoch 37/60
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.8748 - val_accuracy: 0.7708
# Epoch 38/60
# 15/15 [==============================] - 2s 145ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.8452 - val_accuracy: 0.7729
# Epoch 39/60
# 15/15 [==============================] - 2s 145ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.9217 - val_accuracy: 0.7500
# Epoch 40/60
# 15/15 [==============================] - 2s 145ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.7620 - val_accuracy: 0.7896
# Epoch 41/60
# 15/15 [==============================] - 2s 145ms/step - loss: 0.0115 - accuracy: 0.9995 - val_loss: 0.7935 - val_accuracy: 0.7667
# Epoch 42/60
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.8217 - val_accuracy: 0.7667
# Epoch 43/60
# 15/15 [==============================] - 2s 145ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.8463 - val_accuracy: 0.7750
# Epoch 44/60
# 15/15 [==============================] - 2s 145ms/step - loss: 0.0112 - accuracy: 0.9995 - val_loss: 1.1968 - val_accuracy: 0.6750
# Epoch 45/60
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0112 - accuracy: 0.9995 - val_loss: 0.8942 - val_accuracy: 0.7750
# Epoch 46/60
# 15/15 [==============================] - 2s 145ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.8062 - val_accuracy: 0.7792
# Epoch 47/60
# 15/15 [==============================] - 2s 154ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.8829 - val_accuracy: 0.7604
# Epoch 48/60
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.8185 - val_accuracy: 0.7771
# Epoch 49/60
# 15/15 [==============================] - 2s 154ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.8593 - val_accuracy: 0.7812
# Epoch 50/60
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.9919 - val_accuracy: 0.7688
# Epoch 51/60
# 15/15 [==============================] - 2s 154ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.8758 - val_accuracy: 0.7688
# Epoch 52/60
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.9188 - val_accuracy: 0.7604
# Epoch 53/60
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.8644 - val_accuracy: 0.7708
# Epoch 54/60
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.9158 - val_accuracy: 0.7563
# Epoch 55/60
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.8574 - val_accuracy: 0.7729
# Epoch 56/60
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.8874 - val_accuracy: 0.7500
# Epoch 57/60
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.9007 - val_accuracy: 0.7604
# Epoch 58/60
# 15/15 [==============================] - 2s 143ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.8852 - val_accuracy: 0.7792
# Epoch 59/60
# 15/15 [==============================] - 2s 145ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.8928 - val_accuracy: 0.7792
# Epoch 60/60
# 15/15 [==============================] - 2s 143ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.8389 - val_accuracy: 0.7750

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 70 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Saving model
model.save("/content/drive/MyDrive/Colab Notebooks/Data Science End-to-End [50] Project/Data/Data (2)/intel_image.h5")

# %% [markdown]
# We will save the model using model.save() to use it later for prediction.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the training history.

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Next we will plot the loss of the model for the training history.

# %%
# Calculating test accuracy 
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 19/19 [==============================] - 1s 22ms/step - loss: 0.9326 - accuracy: 0.7717
# Test Accuracy: 77.16666460037231

# %% [markdown]
# Evaluating the model to know the accuracy of the model on the test data.

# %%
# Storing model predictions
y_pred = model.predict(x_test)

# %% [markdown]
# Generating predictions for test data and storing them into y_pred.

# %%
# Plotting image to compare
img = array_to_img(x_test[1])
img
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F653F0EFA10>

# %% [markdown]
# Visualizing an image to be predicted in further steps.

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[1])])
print("Predicted : ",labels[np.argmax(y_pred[1])])
# Out:
# ['buildings' 'forest' 'glacier' 'mountain' 'sea' 'street']
# Originally :  sea
# Predicted :  sea

# %% [markdown]
# Now, we will create list of labels using object of label binarizer. We will print that list and finally we will print out the prediction and the original label of the image we visualized above using argmax().

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# In this project we saw how we can create a CNN using different layers. Normalizing is an important step when working with any type of dataset. We will use this model to predict the class of the image supplied to the model.

# %% [markdown]
# ## Scope:

# %% [markdown]
# This project has a vast scope, it can be used to classify satellite images, drone images, google images into different classes like sea, mountain, etc.
